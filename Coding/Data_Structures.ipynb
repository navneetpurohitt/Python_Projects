# %%
// 1. Arrays
// Subtopics:

// Static vs. Dynamic Arrays

// Multidimensional Arrays

// Operations: Insertion, Deletion, Search, Traversal

// Common Problems: Rotations, Subarrays, Prefix Sum, Sliding Window

// Applications: Matrix operations, Dynamic Programming

// 2. Linked Lists
// Subtopics:

// Types:

// Singly Linked List

// Doubly Linked List

// Circular Linked List

// Operations: Insertion, Deletion, Reversal, Cycle Detection

// Applications: LRU Cache, Polynomial Representation

// 3. Stacks
// Subtopics:

// Implementation (Array vs. Linked List)

// LIFO Principle

// Applications: Undo/Redo, Expression Evaluation (Postfix/Infix), DFS

// Monotonic Stacks (for optimization problems)

// 4. Queues
// Subtopics:

// Types:

// Linear Queue

// Circular Queue

// Priority Queue (Heap-based)

// Double-Ended Queue (Deque)

// Operations: Enqueue, Dequeue, Peek

// Applications: BFS, Task Scheduling, Buffering

// 5. Hash Tables
// Subtopics:

// Hash Functions (e.g., Division, Multiplication, Universal Hashing)

// Collision Resolution:

// Open Addressing (Linear/Quadratic Probing, Double Hashing)

// Chaining (Linked Lists, BSTs)

// Load Factor and Rehashing

// Applications: Dictionaries, Frequency Counters, Caching

// 6. Trees
// Subtopics:

// Binary Trees:

// Traversals (Inorder, Preorder, Postorder, Level Order)

// Properties (Height, Depth, Balanced vs. Unbalanced)

// Binary Search Trees (BST):

// Insertion, Deletion, Search

// Inorder Successor/Predecessor

// Applications: Hierarchical Data, Expression Trees

// 7. Heaps
// Subtopics:

// Min-Heap and Max-Heap

// Heapify (Up/Down)

// Priority Queues

// Applications: Dijkstra’s Algorithm, Heap Sort, Top-K Elements

// 8. Advanced Trees
// Subtopics:

// Balanced Trees:

// AVL Trees (Rotations, Balance Factor)

// Red-Black Trees (Insertion/Deletion Rules)

// B-Trees and B+ Trees (for Disk-Based Storage)

// Applications: Databases, File Systems

// 9. Graphs
// Subtopics:

// Representations:

// Adjacency Matrix

// Adjacency List

// Traversals:

// BFS (Shortest Path in Unweighted Graphs)

// DFS (Cycle Detection, Topological Sorting)

// Algorithms:

// Dijkstra’s (Shortest Path)

// Kruskal’s/Prim’s (Minimum Spanning Trees)

// Floyd-Warshall (All-Pairs Shortest Path)

// Applications: Social Networks, Routing Algorithms

// 10. Trie (Prefix Tree)
// Subtopics:

// Structure (Nodes, Edges for Characters)

// Insertion, Deletion, Search

// Applications: Autocomplete, Spell Checkers, IP Routing

// 11. Segment Trees
// Subtopics:

// Range Queries (Sum/Min/Max)

// Lazy Propagation (for Range Updates)

// Applications: Interval Problems, Dynamic Range Queries

// 12. Fenwick Trees (Binary Indexed Trees)
// Subtopics:

// Prefix Sums and Point Updates

// Applications: Frequency Counting, Inversion Count

// 13. Disjoint-Set (Union-Find)
// Subtopics:

// Union by Rank/Size

// Path Compression

// Applications: Kruskal’s Algorithm, Cycle Detection

// 14. Suffix Arrays & Suffix Trees
// Subtopics:

// Suffix Array Construction (Naive vs. Efficient)

// Longest Common Prefix (LCP) Array

// Applications: Substring Search, Genome Analysis

// 15. Bloom Filters
// Subtopics:

// Probabilistic Membership Testing

// False Positive Rate and Hash Functions

// Applications: Caching, Spell Checkers, Network Routers

// 16. Spatial Trees
// Subtopics:

// Quadtree (2D Space Partitioning)

// Octree (3D Space Partitioning)

// K-D Tree (k-dimensional Search)

// Applications: Collision Detection, GIS, Ray Tracing

// 17. Skip Lists
// Subtopics:

// Probabilistic Layered Structure

// Search, Insertion, Deletion (O(log n) Time)

// Applications: Alternative to Balanced Trees

// 18. Circular Buffers
// Subtopics:

// Ring Buffer Implementation

// Applications: Streaming Data, Producer-Consumer Problems

// 19. Fibonacci Heaps
// Subtopics:

// Amortized Analysis

// Decrease Key and Merge Operations

// Applications: Fast Dijkstra’s and Prim’s Algorithms

// 20. Advanced Hashing
// Subtopics:

// Cuckoo Hashing (Multiple Hash Tables)

// Perfect Hashing (Zero Collisions)

// Applications: High-Performance Databases

// 21. Other Advanced Topics
// Persistent Data Structures (Immutable with Versioning)

// Cache-Oblivious Data Structures (Optimized for Memory Hierarchy)

// Wavelet Trees (for Compressed Data Queries)

// Huffman Trees (Data Compression)

// Key Algorithms & Problem-Solving Techniques:
// Greedy Algorithms

// Divide and Conquer

// Dynamic Programming (DP Tables, Memoization)

// Backtracking (State-Space Trees)

// Applications by Domain:
// Databases: B-Trees, Hashing

// Networking: Bloom Filters, Tries

// AI/ML: Graphs, Priority Queues

// Game Development: Spatial Trees, Graphs

# %%
# 🔹 Arrays
# Find the Largest and Smallest Element in an Array

# Reverse an Array

# Sort an Array using Bubble/Selection/Insertion Sort

# Find the Kth Largest/Smallest Element

# Remove Duplicates from a Sorted Array

# 🔹 Strings
# Check if a String is a Palindrome

# Count Vowels, Consonants, Digits and Special Characters

# Reverse a String Without Using Library Functions

# Check if Two Strings are Anagrams

# Find the First Non-Repeating Character in a String

# 🔹 Linked Lists
# Create and Traverse a Singly Linked List

# Insert and Delete Nodes at Beginning, End, and Specific Position

# Reverse a Linked List

# Detect a Loop in a Linked List (Floyd’s Cycle Detection)

# Find the Middle of a Linked List

# 🔹 Stacks
# Implement a Stack using Array

# Implement a Stack using Linked List

# Check for Balanced Parentheses

# Convert Infix Expression to Postfix

# Evaluate a Postfix Expression

# 🔹 Queues
# Implement a Queue using Array

# Implement a Queue using Linked List

# Implement a Circular Queue

# Implement a Deque (Double Ended Queue)

# Generate Binary Numbers from 1 to N using Queue

# Hashing / Hash Tables
# Implement a Hash Table (Open Addressing / Chaining)

# Check for Pair with Given Sum in Array using Hashing

# Count Frequency of Each Element in an Array/String

# Find the First Repeating and Non-Repeating Element

# Group Anagrams Together

# 🔹 Trees
# Create a Binary Tree and Perform Inorder, Preorder, Postorder Traversals

# Level Order Traversal (BFS) of Binary Tree

# Find Height / Depth of a Binary Tree

# Check if Two Binary Trees are Identical

# Print Left/Right View of a Binary Tree

# 🔹 Binary Search Trees (BST)
# Insert, Search, and Delete Nodes in a BST

# Check if a Tree is a Valid BST

# Find Inorder Successor / Predecessor in BST

# Convert BST to a Sorted Linked List

# Find Lowest Common Ancestor (LCA) in BST

# 🔹 Heaps / Priority Queues
# Implement a Min Heap / Max Heap from Scratch

# Insert and Delete in a Heap

# Find K Largest / Smallest Elements Using Heap

# Heap Sort Algorithm

# Merge K Sorted Arrays Using Min Heap

# 🔹 Graphs
# Implement Graph using Adjacency List and Matrix

# DFS and BFS Traversals

# Detect Cycle in Directed and Undirected Graph

# Find Shortest Path using Dijkstra’s Algorithm

# Topological Sort (Kahn’s Algorithm or DFS-based)

# 🔹 Tries (Prefix Trees)
# Insert and Search Words in a Trie

# Auto-Complete Feature using Trie

# Count the Number of Words with a Given Prefix

# Delete a Word from a Trie

# Find Longest Common Prefix in an Array of Strings

# 🔹 Disjoint Set (Union-Find)
# Implement Union-Find (with Union by Rank and Path Compression)

# Detect Cycle in an Undirected Graph using Disjoint Set

# Kruskal’s Algorithm to Find MST using Disjoint Set

# Find Connected Components using Disjoint Set

# Accounts Merge Problem (Leetcode style use-case)

# 🔹 Segment Trees
# Build Segment Tree for Range Sum / Minimum Query

# Update an Element in Segment Tree

# Range Query for Sum / Min / Max

# Lazy Propagation for Range Updates

# Find the First Index with Value Greater Than X in a Range


# 🔹 Fenwick Tree (Binary Indexed Tree - BIT)
# Construct a Binary Indexed Tree for Range Sum Queries

# Point Update and Prefix Sum Query in BIT

# Find the Kth Smallest Element using BIT (Frequency-based)

# Inversion Count of an Array using BIT

# 2D BIT for Range Sum in a Matrix

# 🔹 Suffix Trees / Suffix Arrays
# Construct a Suffix Array using Naive or O(N log² N) Algorithm

# LCP (Longest Common Prefix) Array Construction

# Search a Pattern in Text using Suffix Array

# Construct a Suffix Tree (Ukkonen’s Algorithm)

# Find the Longest Repeated Substring

# 🔹 AVL Trees (Self-Balancing Binary Search Tree)
# Insert Nodes and Automatically Balance AVL Tree

# Delete a Node from AVL Tree

# Perform Rotations (LL, RR, LR, RL)

# Check Balance Factor at Every Node

# AVL Tree Inorder Traversal to Show Sorted Order

# 🔹 Red-Black Trees (Self-Balancing Binary Search Tree)
# Insert Nodes into a Red-Black Tree

# Delete Nodes from Red-Black Tree

# Check Red-Black Tree Properties (e.g., root is black, no two consecutive red nodes)

# Inorder Traversal of Red-Black Tree

# Compare Height of Red-Black Tree vs AVL Tree with Same Insertions

# 🔹 B-Trees / B+ Trees
# Insert into B-Tree (of order t)

# Search for an Element in a B-Tree

# Delete from B-Tree and Handle Underflows

# Construct B+ Tree and Insert Elements

# Range Query in B+ Tree (Leaf-node linked list)

# 🔹 K-D Trees (K-Dimensional Trees)
# Build a 2D K-D Tree (Points with x and y coordinates)

# Range Search (Find points in a given rectangle)

# Nearest Neighbor Search using K-D Tree

# Insert and Delete in K-D Tree

# K Nearest Neighbors (KNN) Query

# 🔹 Skip Lists
# Insert a Node in a Skip List

# Search for an Element in Skip List

# Delete a Node from Skip List

# Compare Skip List Performance with Balanced Trees

# Implement Probabilistic Level Promotion (Random Level Generator)

# 🔹 Bloom Filters
# Design and Implement a Basic Bloom Filter

# Insert and Search in Bloom Filter with Multiple Hash Functions

# Evaluate False Positive Rate with Varying Bit Array Sizes

# Compare Bloom Filter with HashSet for Memory Efficiency

# Implement Counting Bloom Filter to Support Deletions

# %%
# Algorithms"
# 🔹 Sorting Algorithms
# Bubble Sort

# Selection Sort

# Insertion Sort

# Merge Sort

# Quick Sort

# 🔹 Searching Algorithms
# Linear Search

# Binary Search

# Ternary Search

# Jump Search

# Exponential Search

# 🔹 Recursion
# Factorial Calculation

# Fibonacci Series

# Tower of Hanoi

# Generate All Subsets

# Permutations of a String

# 🔹 Divide and Conquer
# Merge Sort

# Quick Sort

# Binary Search

# Closest Pair of Points

# Maximum Subarray (Kadane’s Variation)

# 🔹 Greedy Algorithms
# Activity Selection Problem

# Fractional Knapsack

# Huffman Encoding

# Job Sequencing with Deadlines

# Minimum Platforms (Trains)

# 🔹 Backtracking
# N-Queens Problem

# Sudoku Solver

# Rat in a Maze

# Word Search in Grid

# Subset Sum Problem

# 🔹 Dynamic Programming
# 0/1 Knapsack

# Longest Increasing Subsequence

# Longest Common Subsequence

# Matrix Chain Multiplication

# Edit Distance

# 🔹 Bit Manipulation
# Count Set Bits

# Find Single Number (XOR-based)

# Subset Generation using Bitmask

# Bitwise AND/OR Ranges

# Swap Without Temp Variable

# 🔹 Sliding Window
# Maximum Sum Subarray of Size K

# Longest Substring Without Repeating Characters

# Minimum Window Substring

# Count Anagrams in Substring

# Max in All Subarrays of Size K

# 🔹 Two Pointers
# Pair with Target Sum in Sorted Array

# Remove Duplicates from Sorted Array

# Trapping Rain Water

# 3Sum Problem

# Merge Two Sorted Arrays

# 🔹 Fast and Slow Pointers
# Detect Cycle in Linked List

# Find the Middle of Linked List

# Check Palindrome in Linked List

# Happy Number

# Intersection of Two Linked Lists

# 🔹 Binary Search on Answer
# Allocate Minimum Pages

# Aggressive Cows

# Capacity to Ship Packages Within D Days

# Koko Eating Bananas

# Median of Two Sorted Arrays

# 🔹 DFS (Depth-First Search)
# DFS Traversal of Graph

# Detect Cycle in Graph (DFS)

# Connected Components in Undirected Graph

# Word Search in Grid

# Topological Sort (DFS-based)

# 🔹 BFS (Breadth-First Search)
# BFS Traversal of Graph

# Shortest Path in Unweighted Graph

# Rotten Oranges Problem

# Knight’s Minimum Moves on Chessboard

# Bipartite Graph Check

# 🔹 Topological Sorting
# Kahn’s Algorithm (BFS)

# DFS-Based Topological Sort

# Course Schedule Problem

# All Topological Sorts

# Cycle Detection via Topological Sort

# 🔹 Dijkstra’s Algorithm
# Single-Source Shortest Path in Graph

# Shortest Path in Grid with Weights

# Network Delay Time

# Dijkstra with Priority Queue

# Dijkstra with Path Reconstruction

# 🔹 Bellman-Ford Algorithm
# Single-Source Shortest Path (Handles Negative Weights)

# Detect Negative Weight Cycle

# Currency Arbitrage

# Distance Update in Bellman-Ford

# Compare with Dijkstra

# 🔹 Floyd-Warshall Algorithm
# All Pairs Shortest Path

# Detect Negative Cycle in Directed Graph

# Transitive Closure of Graph

# Minimum Number of Stops between Two Nodes

# APSP for Dense Graphs

# 🔹 A Search Algorithm*
# Pathfinding in a Grid (Manhattan Distance)

# Maze Solving with Obstacles

# Route Optimization (Google Maps style)

# A* with Custom Heuristic

# Comparing A* vs Dijkstra

# 🔹 Union-Find Algorithm
# Disjoint Set Operations (Union by Rank + Path Compression)

# Detect Cycle in Graph

# Kruskal’s Algorithm

# Number of Connected Components

# Accounts Merge

# 🔹 Kruskal’s Algorithm
# Minimum Spanning Tree (MST)

# Redundant Connection Detection

# MST with Union-Find

# Weighted Graph Optimization

# Reverse-Delete Algorithm (for teaching)

# 🔹 Prim’s Algorithm
# MST using Priority Queue

# Lazy vs Eager Prim’s

# Network Cable Laying Cost

# Prim’s on Adjacency List

# Compare Prim vs Kruskal

# 🔹 KMP Algorithm
# Pattern Matching in Linear Time

# LPS (Longest Prefix Suffix) Array Construction

# Substring Search

# Spam Detection in Emails

# DNA Sequence Match

# 🔹 Rabin-Karp Algorithm
# Substring Search using Hashing

# Multiple Pattern Match

# Rolling Hash Implementation

# Detect Plagiarism

# Rabin-Karp vs Naive

# 🔹 Z Algorithm
# Pattern Search using Z-values

# Z-Array Construction

# Count Occurrences of Pattern

# Longest Prefix Match

# Search Multiple Patterns Simultaneously

# 🔹 Boyer-Moore Algorithm
# Pattern Search Using Bad Character Heuristic

# Good Suffix Heuristic Implementation

# Efficient Substring Search

# DNA Matching Optimization

# Compare Boyer-Moore with KMP

# 🔹 Trie-Based Pattern Matching
# Build Trie for Dictionary

# Pattern Search in Trie

# Prefix-based Auto-Suggest

# Word Break Problem

# Wildcard Pattern Matching

# 🔹 Segment Tree Algorithms
# Range Sum Query and Point Update

# Range Minimum Query

# Lazy Propagation for Range Update

# Segment Tree for GCD Queries

# Kth Order Statistic in a Range

# 🔹 Fenwick Tree Algorithms
# Prefix Sum Query and Point Update

# 2D Fenwick Tree

# Range Updates with BIT

# Inversion Count Using BIT

# Kth Element Query via BIT

# 🔹 Convex Hull Algorithms
# Graham’s Scan

# Jarvis March (Gift Wrapping)

# Find Convex Polygon from Set of Points

# Diameter of Convex Hull (Rotating Calipers)

# Closest Pair of Points using Convex Hull

# 🔹 Line Sweep Algorithms
# Find Number of Overlapping Intervals

# Maximum Number of Concurrent Events

# Union of Rectangles

# Skyline Problem

# Closest Pair of Points

# 🔹 Number Theory Algorithms
# GCD & LCM using Euclid’s Algorithm

# Sieve of Eratosthenes

# Modular Exponentiation

# Fermat’s Little Theorem

# Extended Euclidean Algorithm

# 🔹 Matrix Exponentiation
# Fibonacci Number in O(log n)

# Raise Matrix to Power

# Solve Linear Recurrence Relations

# Path Count in Directed Graphs

# State Transitions in DP

# 🔹 Heavy-Light Decomposition
# Path Queries in Tree (Sum/Min/Max)

# LCA with HLD

# Update and Query Path in Log²(N)

# Tree Diameter via HLD

# Combine with Segment Tree

# 🔹 Mo’s Algorithm
# Range Query Optimization (sqrt-decomposition)

# Count Distinct Elements in Range

# Frequency Count Query

# GCD/LCA Queries using Mo’s

# Offline Query Processing

# 🔹 Centroid Decomposition
# Decompose Tree into Subtrees

# Query Update in Decomposed Tree

# Count Distance-K Pairs

# Efficient Queries in Dynamic Trees

# Use in Path Optimization

# 🔹 DP on Trees
# Tree Diameter using DP

# Max Weight Independent Set in Tree

# DP for Subtree Sizes

# Tree Coloring Problem

# Path Sum with DP on Tree

# 🔹 DP on Graphs
# Longest Path in DAG

# Counting Paths in Graph

# DP with Memoization over DAG

# Shortest Path with DP on Grid

# DP + BFS in State Space Graphs

# 🔹 Network Flow Algorithms
# Ford-Fulkerson, Edmonds-Karp, Dinic’s
# Max Flow using Ford-Fulkerson

# Edmonds-Karp (BFS-based Max Flow)

# Dinic’s Algorithm (Blocking Flow)

# Bipartite Matching using Max Flow

# Circulation with Demands
