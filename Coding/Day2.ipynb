# %%
# Basic Concepts - Completed
# Hello World
# Print "Hello, World!" to the console.
# Input: None
# Output: Hello, World!

# Sum of Two Numbers
# Take two integers as input and print their sum.
# Input: 3 5
# Output: 8

# Check Even or Odd
# Check if a number is even or odd.
# Input: 7
# Output: Odd

# Factorial Using Loop
# Calculate the factorial of a number using a loop.
# Input: 5
# Output: 120

# Fibonacci Sequence
# Generate the first n Fibonacci numbers.
# Input: 5
# Output: [0, 1, 1, 2, 3]

# Check Prime Number
# Determine if a number is prime.
# Input: 13
# Output: True

# Reverse a String
# Reverse a string without using built-in functions.
# Input: "hello"
# Output: "olleh"

# Palindrome Check
# Check if a string is a palindrome.
# Input: "madam"
# Output: True

# Find Maximum in a List
# Find the largest number in a list.
# Input: [4, 2, 9, 5]
# Output: 9

# Sort a List Without Built-in Functions
# Sort a list in ascending order.
# Input: [3, 1, 4, 2]
# Output: [1, 2, 3, 4]

# %%
# Intermediate Concepts - Completed
# Count Occurrences in a String
# Count the frequency of each character in a string.
# Input: "apple"
# Output: {'a':1, 'p':2, 'l':1, 'e':1}

# Calculate Simple Interest
# Compute simple interest given principal, rate, and time.
# Input: 1000 5 2 (principal, rate, time)
# Output: 100.0

# Check Leap Year
# Determine if a year is a leap year.
# Input: 2024
# Output: True

# Merge Two Dictionaries
# Merge two dictionaries into one.
# Input: {'a':1}, {'b':2}
# Output: {'a':1, 'b':2}

# Find Common Elements in Two Lists
# Find the intersection of two lists.
# Input: [1,2,3], [2,3,4]
# Output: [2, 3]

# Binary Search
# Implement binary search on a sorted list.
# Input: [1,2,3,4,5], target=3
# Output: 2 (index)

# Count Words in a File
# Count the number of words in a text file.
# Input: File with content "Hello world"
# Output: 2

# Convert Celsius to Fahrenheit
# Convert a temperature from Celsius to Fahrenheit.
# Input: 30
# Output: 86.0

# Command-Line Arguments
# Print the sum of command-line arguments.
# Input: python script.py 3 5
# Output: 8

# Generate Random Numbers
# Generate 5 random integers between 1 and 100.
# Output: [12, 45, 67, 89, 3] (example)

# %%
# Advanced Concepts
# List Comprehension: Squares
# Create a list of squares using list comprehension.
# Input: [1,2,3,4]
# Output: [1,4,9,16]

# Check Perfect Number
# *Check if a number is a perfect number (e.g., 6 = 1+2+3).*
# Input: 28
# Output: True

# Sort List of Tuples by Second Element
# Sort [(2,5), (1,3), (4,1)] by the second item.
# Output: [(4,1), (1,3), (2,5)]

# Count Vowels in a String
# Count the number of vowels in a string.
# Input: "hello"
# Output: 2

# Matrix Multiplication
# Multiply two matrices.
# Input: [[1,2],[3,4]], [[5,6],[7,8]]
# Output: [[19,22], [43,50]]

# Decorator to Measure Execution Time
# Create a decorator to time a function.
# Output: (Prints the time taken by the function)

# Generator for Even Numbers
# Create a generator that yields even numbers up to n.
# Input: 5
# Output: 0, 2, 4

# Handle Division by Zero
# Handle division by zero exception.
# Input: 5/0
# Output: "Cannot divide by zero!"

# Recursive Power Calculation
# Calculate x^y using recursion.
# Input: 2 3
# Output: 8

# Regular Expression: Extract Email Addresses
# Extract email addresses from a string.
# Input: "Email me at user@example.com"
# Output: ['user@example.com']

# %%
# OOP and Data Structures
# Linked List Traversal
# Implement a linked list and traverse it.
# Input: 1 -> 2 -> 3
# Output: 1 2 3

# Binary Tree Inorder Traversal
# Traverse a binary tree in inorder.
# Input: (Tree with root 1, left 2, right 3)
# Output: 2 1 3

# Bubble Sort Implementation
# Sort a list using bubble sort.
# Input: [4, 2, 5, 1]
# Output: [1, 2, 4, 5]

# Check Armstrong Number
# Check if a number is an Armstrong number (e.g., 153).
# Input: 153
# Output: True

# Check Anagram
# Check if two strings are anagrams.
# Input: "listen", "silent"
# Output: True

# Exception Handling for File Operations
# Handle FileNotFoundError when opening a file.
# Input: (Non-existent file)
# Output: "File not found!"

# Multithreading Example
# Print numbers and letters using two threads.
# Output:

# 1 a 2 b 3 c
# Memoization for Fibonacci
# Optimize Fibonacci using memoization.
# Input: 10
# Output: 55

# Reverse Words in a String
# Reverse the order of words in a string.
# Input: "Hello world"
# Output: "world Hello"

# Calculate GCD Using Recursion
# Find the GCD of two numbers recursively.
# Input: 56 98
# Output: 14

# Advanced Algorithms
# Zip Two Lists into a Dictionary
# Combine two lists into a dictionary.
# Input: ["a","b"], [1,2]
# Output: {'a':1, 'b':2}

# Implement a Stack
# Implement stack operations (push, pop).
# Input: push(1), push(2), pop()
# Output: 2

# Queue Using Collections.deque
# Implement a queue using deque.
# Input: enqueue(1), enqueue(2), dequeue()
# Output: 1

# Sieve of Eratosthenes
# Generate all primes up to n.
# Input: 10
# Output: [2, 3, 5, 7]

# Check Balanced Parentheses
# Check if parentheses in a string are balanced.
# Input: "({[]})"
# Output: True

# Rotate List by k Positions
# Rotate a list to the right by k.
# Input: [1,2,3,4], k=2
# Output: [3,4,1,2]

# Word Frequency from File
# Count the frequency of each word in a file.
# Input: (File with "hello world hello")
# Output: {'hello':2, 'world':1}

# Binary to Decimal Conversion
# Convert a binary string to decimal.
# Input: "1010"
# Output: 10

# Permutations of a String
# Generate all permutations of a string.
# Input: "abc"
# Output: ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# Multithreaded Counter
# Increment a counter using two threads (with locks).
# Output: (Counter value after increments)
