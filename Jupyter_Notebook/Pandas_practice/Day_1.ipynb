# %%
import numpy as np
import pandas as pd
import matplotlib_inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Dataset.csv')

# %%
df
# Out:
#                Date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal  \
# 0         July 2004  0.34  0.36  10.01  4.68   0.42  0.00           2.80
# 1       August 2004  0.35  0.36   9.74  4.96   0.46  0.00           2.65
# 2    September 2004  0.41  0.41   9.59  5.04   0.51  0.00           2.64
# 3      October 2004  0.40  0.38   9.47  5.29   0.53  0.00           2.76
# 4     November 2004  0.38  0.38   9.48  5.22   0.55  0.00           2.75
# ..              ...   ...   ...    ...   ...    ...   ...            ...
# 241     August 2024  0.62  0.96   6.36  6.67   0.20  0.93           0.06
# 242  September 2024  0.65  1.00   6.49  6.66   0.23  0.90           0.05
# 243    October 2024  0.64  1.03   6.75  6.59   0.24  0.94           0.03
# 244   November 2024  0.64  1.12   6.92  6.49   0.19  0.95           0.03
# 245   December 2024  0.64  1.13   7.06  6.42   0.15  0.93           0.05
#
#        Go  Groovy  ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Abap', 'Ada', 'C/C++', 'C#', 'Cobol', 'Dart', 'Delphi/Pascal',
#        'Go', 'Groovy', 'Haskell', 'Java', 'JavaScript', 'Julia', 'Kotlin',
#        'Lua', 'Matlab', 'Objective-C', 'Perl', 'PHP', 'Powershell', 'Python',
#        'R', 'Ruby', 'Rust', 'Scala', 'Swift', 'TypeScript', 'VBA',
#        'Visual Basic'],
#       dtype='object')

# %%
df.rename(columns= {'Date': 'date', "Groovy": 'Groo'}, inplace= True)

# %%
df.head()
# Out:
#              date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  \
# 0       July 2004  0.34  0.36  10.01  4.68   0.42   0.0           2.80  0.0
# 1     August 2004  0.35  0.36   9.74  4.96   0.46   0.0           2.65  0.0
# 2  September 2004  0.41  0.41   9.59  5.04   0.51   0.0           2.64  0.0
# 3    October 2004  0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0
# 4   November 2004  0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0
#
#    Groo  ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  TypeScript  \
# 0  0.03  ...        0.16    2.51  0.39  0.33  0.24   0.17    0.0         0.0
# 1  0.07  ...        0.15    2.62  0.40  0.40  0.19   0.17    0.0         0.0
# 2  0.08  ...        0.08    2.71  0.40  0.41  0.17   0.13    0.0         0.0
# 3  0.09  ...        0.12    2.91  0.42  0.46  0.12   0.14    0.0         0.0
# 4  0.07  ...        0.12    2.83  0.41  0.44  0.17   0.15    0.0         0.0
#
#     VBA  Visual Basic
# 0  1.43          8.50
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
# Out:
# C:\Users\DC\AppData\Local\Temp\ipykernel_17016\3532345252.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#         date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  Groo  \
# 0 2004-07-01  0.34  0.36  10.01  4.68   0.42   0.0           2.80  0.0  0.03
# 1 2004-08-01  0.35  0.36   9.74  4.96   0.46   0.0           2.65  0.0  0.07
# 2 2004-09-01  0.41  0.41   9.59  5.04   0.51   0.0           2.64  0.0  0.08
# 3 2004-10-01  0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0  0.09
# 4 2004-11-01  0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0  0.07
#
#    ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  TypeScript   VBA  \
# 0  ...        0.16    2.51  0.39  0.33  0.24   0.17    0.0         0.0  1.43
# 1  ...        0.15    2.62  0.40  0.40  0.19   0.17    0.0         0.0  1.45
# 2  ...        0.08    2.71  0.40  0.41  0.17   0.13    0.0         0.0  1.54
# 3  ...        0.12    2.91  0.42  0.46  0.12   0.14    0.0         0.0  1.61
# 4  ...        0.12    2.83  0.41  0.44  0.17   0.15    0.0         0.0  1.50
#
#    Visual Basic
# 0          8.50
# ...

# %%
filtered_df = df[df['date'] > '2004-09-01']

# %%
filtered_df.head()
# Out:
#         date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  Groo  \
# 3 2004-10-01  0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0  0.09
# 4 2004-11-01  0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0  0.07
# 5 2004-12-01  0.36  0.37   9.53  5.22   0.53   0.0           2.76  0.0  0.09
# 6 2005-01-01  0.39  0.38   9.69  5.23   0.56   0.0           2.65  0.0  0.11
# 7 2005-02-01  0.37  0.39   9.86  5.20   0.49   0.0           2.66  0.0  0.07
#
#    ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  TypeScript   VBA  \
# 3  ...        0.12    2.91  0.42  0.46  0.12   0.14    0.0        0.00  1.61
# 4  ...        0.12    2.83  0.41  0.44  0.17   0.15    0.0        0.00  1.50
# 5  ...        0.04    2.70  0.39  0.42  0.19   0.12    0.0        0.00  1.45
# 6  ...        0.04    2.91  0.39  0.47  0.15   0.09    0.0        0.00  1.50
# 7  ...        0.05    2.87  0.38  0.45  0.16   0.09    0.0        0.01  1.45
#
#    Visual Basic
# 3          8.46
# ...

# %%
df.head()
# Out:
#         date  Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal   Go  Groo  \
# 0 2004-07-01  0.34  0.36  10.01  4.68   0.42   0.0           2.80  0.0  0.03
# 1 2004-08-01  0.35  0.36   9.74  4.96   0.46   0.0           2.65  0.0  0.07
# 2 2004-09-01  0.41  0.41   9.59  5.04   0.51   0.0           2.64  0.0  0.08
# 3 2004-10-01  0.40  0.38   9.47  5.29   0.53   0.0           2.76  0.0  0.09
# 4 2004-11-01  0.38  0.38   9.48  5.22   0.55   0.0           2.75  0.0  0.07
#
#    ...  Powershell  Python     R  Ruby  Rust  Scala  Swift  TypeScript   VBA  \
# 0  ...        0.16    2.51  0.39  0.33  0.24   0.17    0.0         0.0  1.43
# 1  ...        0.15    2.62  0.40  0.40  0.19   0.17    0.0         0.0  1.45
# 2  ...        0.08    2.71  0.40  0.41  0.17   0.13    0.0         0.0  1.54
# 3  ...        0.12    2.91  0.42  0.46  0.12   0.14    0.0         0.0  1.61
# 4  ...        0.12    2.83  0.41  0.44  0.17   0.15    0.0         0.0  1.50
#
#    Visual Basic
# 0          8.50
# ...

# %%
df.isnull().sum()
# Out:
# date             0
# Abap             0
# Ada              0
# C/C++            0
# C#               0
# Cobol            0
# Dart             0
# Delphi/Pascal    0
# Go               0
# Groo             0
# Haskell          0
# Java             0
# JavaScript       0
# Julia            0
# Kotlin           0
# Lua              0
# Matlab           0
# Objective-C      0
# Perl             0
# PHP              0
# Powershell       0
# Python           0
# R                0
# Ruby             0
# Rust             0
# Scala            0
# Swift            0
# TypeScript       0
# VBA              0
# Visual Basic     0
# dtype: int64

# %%
df.describe()
# Out:
#                                 date        Abap         Ada       C/C++  \
# count                            246  246.000000  246.000000  246.000000
# mean   2014-09-15 21:45:21.951219456    0.497073    0.413699    7.998211
# min              2004-07-01 00:00:00    0.320000    0.090000    5.480000
# 25%              2009-08-08 18:00:00    0.410000    0.230000    6.622500
# 50%              2014-09-16 00:00:00    0.485000    0.330000    7.880000
# 75%              2019-10-24 06:00:00    0.580000    0.497500    8.617500
# max              2024-12-01 00:00:00    0.760000    1.140000   12.890000
# std                              NaN    0.107139    0.263013    1.750864
#
#                C#       Cobol        Dart  Delphi/Pascal          Go  \
# count  246.000000  246.000000  246.000000     246.000000  246.000000
# mean     7.432764    0.356585    0.237764       0.895122    0.599634
# min      4.680000    0.150000    0.000000       0.000000    0.000000
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 246 entries, 0 to 245
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           246 non-null    datetime64[ns]
#  1   Abap           246 non-null    float64
#  2   Ada            246 non-null    float64
#  3   C/C++          246 non-null    float64
#  4   C#             246 non-null    float64
#  5   Cobol          246 non-null    float64
#  6   Dart           246 non-null    float64
#  7   Delphi/Pascal  246 non-null    float64
#  8   Go             246 non-null    float64
#  9   Groo           246 non-null    float64
#  10  Haskell        246 non-null    float64
#  11  Java           246 non-null    float64
#  12  JavaScript     246 non-null    float64
#  13  Julia          246 non-null    float64
#  14  Kotlin         246 non-null    float64
#  15  Lua            246 non-null    float64
#  16  Matlab         246 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['date', 'Abap', 'Ada', 'C/C++', 'C#', 'Cobol', 'Dart', 'Delphi/Pascal',
#        'Go', 'Groo', 'Haskell', 'Java', 'JavaScript', 'Julia', 'Kotlin', 'Lua',
#        'Matlab', 'Objective-C', 'Perl', 'PHP', 'Powershell', 'Python', 'R',
#        'Ruby', 'Rust', 'Scala', 'Swift', 'TypeScript', 'VBA', 'Visual Basic'],
#       dtype='object')

# %%
sns.displot(x = df['date'],y=df['Python'])

# %%
sns.barplot(x = df['date'], y = df['Python'])
# Out:
# <Axes: xlabel='date', ylabel='Python'>

# %%
sns.catplot(df)

# %%
sns.catplot(x = df['date'], y = df['Python'])
